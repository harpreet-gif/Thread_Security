# %%
name = "Harpreet"
department = "CSE"
id = "1234"

employee = input("Enter name:")
if employee == name:
  emp_id = input("Enter id:")

  if emp_id == id:
    print("Name", name)
    print("Department:", department)
    print("Id:", id)

  else:
    print("Id doesn't exsist")

else:
  print("Employee doesn't exsist")
# Out:
# Enter name:Harpreet
# Enter id:1234
# Name Harpreet
# Department: CSE
# Id: 1234

# %%
for i in range(5):
  name = input("Enter name:")
  print(name)
# Out:
# Enter name:harpreet
# harpreet
# Enter name:harpreet
# harpreet
# Enter name:harpreet
# harpreet
# Enter name:harpreet
# harpreet
# Enter name:harpreet
# harpreet
