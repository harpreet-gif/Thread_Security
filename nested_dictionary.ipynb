# %%
students = {
    "student1":{
        "name":"Harpreet",
        "age":"19"
    },
    "student2":{
        "name":"Riya",
        "age":"20"
    },
    "student3":{
        "name":"Rahul",
        "age":"21"
}
    }

print(students)
# Out:
# {'student1': {'name': 'Harpreet', 'age': '19'}, 'student2': {'name': 'Riya', 'age': '20'}, 'student3': {'name': 'Rahul', 'age': '21'}}

# %%
print(students["student1"]["name"])
# Out:
# Harpreet

# %%
print(students["student3"]["age"])
# Out:
# 21

# %%
students["student2"]["age"] = 21
print(students["student2"])
# Out:
# {'name': 'Riya', 'age': 21}

# %%
students["student4"] = {
    "name": "Simran",
    "age": 20
}

print(students)
# Out:
# {'student1': {'name': 'Harpreet', 'age': '19'}, 'student2': {'name': 'Riya', 'age': 21}, 'student3': {'name': 'Rahul', 'age': '21'}, 'student4': {'name': 'Simran', 'age': 20}}
